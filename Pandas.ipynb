# %%
import pandas as pd

# %%
# df=pd.read_excel(r'C:\Users\gupta\Downloads\Attribute DataSet.xlsx')

# %%
# df # df is the dataframe dataframe is the tabular structure
# print(type(df))

# %%
# df

# %%
# If we want to select the another excel sheet from the same excel sheet
df1 = pd.read_excel(r'C:\Users\gupta\Downloads\Attribute DataSet.xlsx',sheet_name='Sheet2')
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # If we want to select the another excel sheet from the same excel sheet
# ----> 2 df1 = pd.read_excel(r'C:\Users\gupta\Downloads\Attribute DataSet.xlsx',sheet_name='Sheet2')
#       3 df1
#
# File c:\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
# ...

# %%
# It will consider the top of the row which is heading also the column

# %%
df=pd.read_excel(r'C:\Users\gupta\Downloads\Attribute DataSet.xlsx',header=None) # By placing header=None it will replace the column detail with the integer number
df
# Out:
#              0        1        2       3     4       5          6
# 0      Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 1    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 2    1212192089   Casual      Low       0     L  Summer     o-neck
# 3    1190380701  vintage     High       0     L  Automn     o-neck
# 4     966005983    Brief  Average     4.6     L  Spring     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 496   713391965   Casual      Low     4.7     M  Spring     o-neck
# 497   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 498   532874347   Casual  Average     4.7     M  Summer     v-neck
# 499   655464934   Casual  Average     4.6     L  winter  boat-neck
# 500   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#                7          8           9           10          11
# 0    SleeveLength  waiseline    Material  FabricType  Decoration  \
# ...

# %%
df=pd.read_excel(r'C:\Users\gupta\Downloads\Attribute DataSet.xlsx',header=None,names=['A' ,'B','C','D','E','F','G','H','I','J','K','L','M']) # Here we can also change the name of the column
df
# Out:
#                   A        B       C     D       E          F             G
# Dress_ID      Style    Price  Rating  Size  Season   NeckLine  SleeveLength  \
# 1006032852     Sexy      Low     4.6     M  Summer     o-neck     sleevless
# 1212192089   Casual      Low       0     L  Summer     o-neck         Petal
# 1190380701  vintage     High       0     L  Automn     o-neck          full
# 966005983     Brief  Average     4.6     L  Spring     o-neck          full
# ...             ...      ...     ...   ...     ...        ...           ...
# 713391965    Casual      Low     4.7     M  Spring     o-neck          full
# 722565148      Sexy      Low     4.3  free  Summer     o-neck          full
# 532874347    Casual  Average     4.7     M  Summer     v-neck          full
# 655464934    Casual  Average     4.6     L  winter  boat-neck     sleevless
# 919930954    Casual      Low     4.4  free  Summer     v-neck         short
#
# ...

# %%
# Different types of operation on the dataframe
df=pd.read_excel(r'C:\Users\gupta\Downloads\Attribute DataSet.xlsx')
# For seeing the specific number of rows from the top in the dataframe
df.head(2) # It will show the top two data
df.head() # If we will not give any argument in it it will give you the top 5 data
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless  \
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
# For seeing the specific number of rows from the bottom in the dataframe
df.tail() # If we will not give any argument in it it will give you the bottom 5 data
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full  \
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
df.tail(2) # It will show the bottom two data
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless  \
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
df_h = pd.read_csv(r'C:\Users\gupta\Downloads\haberman_csv.csv')
df_h
# Out:
#      Age_of_patient_at_time_of_operation  Patients_year_of_operation
# 0                                     30                          64  \
# 1                                     30                          62
# 2                                     30                          65
# 3                                     31                          59
# 4                                     31                          65
# ..                                   ...                         ...
# 301                                   75                          62
# 302                                   76                          67
# 303                                   77                          65
# 304                                   78                          65
# 305                                   83                          58
#
#      Number_of_positive_axillary_nodes_detected  Survival_status
# 0                                             1                1
# ...

# %%
 # Reading the data directly from the github
df_github = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Printing the data set df_github
df_github
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Python311\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Python311\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Python311\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
# Reading the data from the html page
df_basketball=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df_basketball
type(df_basketball) # It is the list it is not the dataframe
len(df_basketball) # Length is the 1 because there is only one table
df_basketball[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  \
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# If we want to read the json data
json_df = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
json_df
type(json_df)
json_df .columns # If we want to show the name of the column
json_df['user'] # Under the user these is the data
# Out:
# 0     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 1     {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 2     {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 3     {'login': 'attack68', 'id': 24256554, 'node_id...
# 4     {'login': 'attack68', 'id': 24256554, 'node_id...
# 5     {'login': 'AlexanderJuestel', 'id': 45469915, ...
# 6     {'login': 'ChiQiao', 'id': 35905338, 'node_id'...
# 7     {'login': 'rmhowe425', 'id': 45905457, 'node_i...
# 8     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 9     {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 10    {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 11    {'login': 'kvn4', 'id': 55560840, 'node_id': '...
# 12    {'login': 'WillAyd', 'id': 609873, 'node_id': ...
# 13    {'login': 'Julian048', 'id': 100482381, 'node_...
# 14    {'login': 'raj-thapa', 'id': 118627384, 'node_...
# 15    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 16    {'login': 'Rob-DL', 'id': 3153796, 'node_id': ...
# ...

# %%
# Here we are seeing the attribute dataframe
df
# Now we want to convert these data into the json
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck  \
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration
# 0      sleevless    empire            NaN     chiffon     ruffles  \
# ...

# %%
df.to_json('test.json',orient='records') # Giving the name of the test file

# %%
pwd
# Out:
# 'c:\\Users\\gupta\\OneDrive\\Desktop\\Ineron(Python and Pandas)'

# %%
# Now we are saving our csv data into our system
df.to_csv("C://test1.csv")
df.to_csv("C://test1.csv",sep='#') # All the data are seperated with the #
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\compat\_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File c:\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'fsspec'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# We know the mysql
# 1-> Create a table attribute and dress dataset
# 2-> Do a bulk for these two table for respective dataset
# 3-> Read these dataset in pandas as a dataframe
# 4-> Convert attribute dataset in json format
# 5-> Store the json dataset in the mongodb

# 6-> In sql task try to perform left join operation with attribute dataset and dress dataset on column Dress_ID
# 7-> Write a sql query to find out how many unique dress that we have based on dress id
# 8-> How many dresses have recommendation 0
# 9-> Try to find out the total dress sell from indivisual dress id
# 10-> Try to find out a third highest most selling dress id

# %%
df_attribute = pd.read_csv(r'C:\Users\gupta\Downloads\Attribute DataSet_CSV.csv')
df_attribute
# Out:
#        Dress_ID     Style    Price Rating  Size  Season         NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low      0     L  Summer           o-neck
# 2    1190380701   vintage     High      0     L  Automn           o-neck
# 3     966005983     Brief  Average    4.6     L  Spring           o-neck
# 4     876339541      cute      Low    4.5     M  Summer           o-neck
# ..          ...       ...      ...    ...   ...     ...              ...
# 515  1055411544    Casual      Low      5     M  Summer        boat-neck
# 516  1162628131    Casual      Low      0  free  Winter        boat-neck
# 517   624314841      cute  Average    4.7     L  spring           o-neck
# 518   830467746  bohemian   Medium      5  free  Automn           o-neck
# 519   840857118     Brief  Average      0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline       Material FabricType  Decoration
# ...

# %%
df_dress = pd.read_csv(r'C:\Users\gupta\Downloads\Dress-Sales_CSV.csv')
df_dress
# Out:
#        Dress_ID  29-08-2013  31-08-2013  02-09-2013  04-09-2013  06-09-2013
# 0    1006032852        2114        2274        2491        2660        2727  \
# 1    1212192089         151         275         570         750         813
# 2    1190380701           6           7           7           7           8
# 3     966005983        1005        1128        1326        1455        1507
# 4     876339541         996        1175        1304        1396        1432
# ..          ...         ...         ...         ...         ...         ...
# 495   713391965           0           0           0         560         554
# 496   722565148           0           0           0         875         866
# 497   532874347           0           0           0         734         728
# 498   655464934           0           0           0         254         259
# 499   919930954           0           0           0         538         545
#
# ...

# %%
df_attribute.to_json('attribute.json')

# %%
pwd
# Out:
# 'c:\\Users\\gupta\\OneDrive\\Desktop\\Ineron(Python and Pandas)'

# %%
# Loading the attribute dataset
df_attribute = pd.read_csv(r'C:\Users\gupta\Downloads\Attribute DataSet_CSV.csv')
df_attribute
# Out:
#        Dress_ID     Style    Price Rating  Size  Season         NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low      0     L  Summer           o-neck
# 2    1190380701   vintage     High      0     L  Automn           o-neck
# 3     966005983     Brief  Average    4.6     L  Spring           o-neck
# 4     876339541      cute      Low    4.5     M  Summer           o-neck
# ..          ...       ...      ...    ...   ...     ...              ...
# 515  1055411544    Casual      Low      5     M  Summer        boat-neck
# 516  1162628131    Casual      Low      0  free  Winter        boat-neck
# 517   624314841      cute  Average    4.7     L  spring           o-neck
# 518   830467746  bohemian   Medium      5  free  Automn           o-neck
# 519   840857118     Brief  Average      0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline       Material FabricType  Decoration
# ...

# %%
# If we want name of all the columns of the dataset
df_attribute.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation'],
#       dtype='object')

# %%
# If we want to see the data of the particular column onlu
df_attribute['Rating']
# Checking the data type of the above column
type(df_attribute['Rating']) # Series_> Almost equivalent to the list
# Two types of data frame in Pandas 1-> Dataframe 2-> Series
# Out:
# pandas.core.series.Series

# %%
# If we want to see all the datatypes of all the columns
df_attribute.dtypes
# Out:
# Dress_ID          object
# Style             object
# Price             object
# Rating            object
# Size              object
# Season            object
# NeckLine          object
# SleeveLength      object
# waiseline         object
# Material          object
# FabricType        object
# Decoration        object
# Pattern Type      object
# Recommendation    object
# dtype: object

# %%
# If we want to fetch more than one column in the pandas
# df_attribute['Price','Size'] # These will give an error
# You have to pass inside the list
df_attribute[['Price','Size']]
# Out:
#        Price  Size
# 0        Low     M
# 1        Low     L
# 2       High     L
# 3    Average     L
# 4        Low     M
# ..       ...   ...
# 515      Low     M
# 516      Low  free
# 517  Average     L
# 518   Medium  free
# 519  Average     M
#
# [520 rows x 2 columns]

# %%
# If you have provided column name as a list like these [['profit']] the data type is Dataframe and if you have provided like these than the datatype will be Series

# %%
# If we want to see the statistics about the dataset
df_attribute.describe()
# Out:
#           Dress_ID   Style    Price Rating Size  Season NeckLine SleeveLength
# count          520     520      520    520  520     518      517          518  \
# unique         476      14        8     18    8       9       17           18
# top     1219677488  Casual  Average      0    M  Summer   o-neck    sleevless
# freq             3     236      261    130  184     168      283          226
#
#        waiseline Material FabricType Decoration Pattern Type Recommendation
# count        427      388        245        277          408            520
# unique         5       24         23         25           15              3
# top      natural   cotton    chiffon       lace        solid              0
# freq         313      158        140         74          208            301

# %%
# Filtering the data on the basis of the object
df_attribute.dtypes=='object' # Here I do not have any int objects
# Out:
# Dress_ID          True
# Style             True
# Price             True
# Rating            True
# Size              True
# Season            True
# NeckLine          True
# SleeveLength      True
# waiseline         True
# Material          True
# FabricType        True
# Decoration        True
# Pattern Type      True
# Recommendation    True
# dtype: bool

# %%
a = df_attribute.dtypes[df_attribute.dtypes=='object'].index # I am getting all the column whose data type is object in the form of the list
print(a)
# print(a[0]) # a is the list type of data so on printing a[0] we will get the first element 
# If we want to get the data which is present in the column which is in a or in 
print(df_attribute[df_attribute.dtypes[df_attribute.dtypes=='object'].index])
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation'],
#       dtype='object')
#        Dress_ID     Style    Price Rating  Size  Season         NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low      0     L  Summer           o-neck
# 2    1190380701   vintage     High      0     L  Automn           o-neck
# 3     966005983     Brief  Average    4.6     L  Spring           o-neck
# 4     876339541      cute      Low    4.5     M  Summer           o-neck
# ..          ...       ...      ...    ...   ...     ...              ...
# 515  1055411544    Casual      Low      5     M  Summer        boat-neck
# 516  1162628131    Casual      Low      0  free  Winter        boat-neck
# 517   624314841      cute  Average    4.7     L  spring           o-neck
# ...

# %%
df_attribute[df_attribute.dtypes[df_attribute.dtypes=='object'].index].describe()
# Out:
#           Dress_ID   Style    Price Rating Size  Season NeckLine SleeveLength
# count          520     520      520    520  520     518      517          518  \
# unique         476      14        8     18    8       9       17           18
# top     1219677488  Casual  Average      0    M  Summer   o-neck    sleevless
# freq             3     236      261    130  184     168      283          226
#
#        waiseline Material FabricType Decoration Pattern Type Recommendation
# count        427      388        245        277          408            520
# unique         5       24         23         25           15              3
# top      natural   cotton    chiffon       lace        solid              0
# freq         313      158        140         74          208            301

# %%
# If I am seeing the float datatype
df_attribute.dtypes=='float' # ALl the columns are comming false beacause I do not have any float datatype
df_attribute.dtypes[df_attribute.dtypes=='float']
df_attribue.dtypes[]
# Series is just like the list
# Out:
# Series([], dtype: object)

# %%
df_attribute.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation'],
#       dtype='object')

# %%
# If we want to see the data of the particuar column from one index to another index so we can use list indexing
df_attribute['Size'][1:4]
# Out:
# 1    L
# 2    L
# 3    L
# Name: Size, dtype: object

# %%
df_attribute['Size'][0:2]
# Out:
# 0    M
# 1    L
# Name: Size, dtype: object

# %%
# We can also give the jump size
df_attribute['Size'][1:40:2]
# Out:
# 1        L
# 3        L
# 5        M
# 7     free
# 9     free
# 11    free
# 13       M
# 15    free
# 17    free
# 19       M
# 21       M
# 23       S
# 25       M
# 27       L
# 29       M
# 31       M
# 33       L
# 35    free
# 37       M
# 39       M
# Name: Size, dtype: object

# %%
# If we want to add the new column in the dataset
# df_attribute['a'] # a column does not exist giving KeyError
df_attribute['category1']='sudh'
# A new column name category1 is added in the dataset and the value 'sudh' is assigned to the whole column

# %%
df_attribute
# Out:
#        Dress_ID     Style    Price Rating  Size  Season         NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low      0     L  Summer           o-neck
# 2    1190380701   vintage     High      0     L  Automn           o-neck
# 3     966005983     Brief  Average    4.6     L  Spring           o-neck
# 4     876339541      cute      Low    4.5     M  Summer           o-neck
# ..          ...       ...      ...    ...   ...     ...              ...
# 515  1055411544    Casual      Low      5     M  Summer        boat-neck
# 516  1162628131    Casual      Low      0  free  Winter        boat-neck
# 517   624314841      cute  Average    4.7     L  spring           o-neck
# 518   830467746  bohemian   Medium      5  free  Automn           o-neck
# 519   840857118     Brief  Average      0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline       Material FabricType  Decoration
# ...

# %%
df_attribute.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation', 'category1'],
#       dtype='object')

# %%
# If we want to check whether in the Price column anything is null or not
df_attribute['Price'].isnull()
# If it is null then it is True and if it is not null then it is False
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 515    False
# 516    False
# 517    False
# 518    False
# 519    False
# Name: Price, Length: 520, dtype: bool

# %%
df_attribute['waiseline'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 515     True
# 516     True
# 517     True
# 518    False
# 519    False
# Name: waiseline, Length: 520, dtype: bool

# %%
df_attribute['waiseline'][16]
# Out:
# nan

# %%
# We want that id of the DressID and the all detail where rating is the maximun
df_attribute[df_attribute['Rating'] == max(df_attribute['Rating'])]['Material']
# Out:
# 500    Material
# Name: Material, dtype: object

# %%
df_attribute['Season']=='Winter'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 515    False
# 516     True
# 517    False
# 518    False
# 519     True
# Name: Season, Length: 520, dtype: bool

# %%
df_attribute[df_attribute['Season']=='Winter']
# Out:
#        Dress_ID    Style    Price Rating  Size  Season         NeckLine
# 12    957723897     sexy      Low    4.7     M  Winter           o-neck  \
# 15   1162628131   Casual      Low      0  free  Winter        boat-neck
# 18    840857118    Brief  Average      0     M  Winter  peterpan-collor
# 35    640823350   Casual      Low    4.6  free  Winter        boat-neck
# 36    801861988  vintage  Average    4.6  free  Winter           o-neck
# ..          ...      ...      ...    ...   ...     ...              ...
# 409  1135456589   Casual  Average      0    XL  Winter           v-neck
# 421   860334943   Casual   Medium    4.9     L  Winter           o-neck
# 513   957723897     sexy      Low    4.7     M  Winter           o-neck
# 516  1162628131   Casual      Low      0  free  Winter        boat-neck
# 519   840857118    Brief  Average      0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline  Material  FabricType Decoration Pattern Type
# ...

# %%
len(df_attribute[df_attribute['Season']=='Winter'])
# Out:
# 102

# %%
df_attribute['Rating']>'3'
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 515     True
# 516    False
# 517     True
# 518     True
# 519    False
# Name: Rating, Length: 520, dtype: bool

# %%
df_attribute[df_attribute['Rating']>'3']
# Out:
#        Dress_ID     Style    Price Rating  Size  Season   NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer     o-neck  \
# 3     966005983     Brief  Average    4.6     L  Spring     o-neck
# 4     876339541      cute      Low    4.5     M  Summer     o-neck
# 10   1117293701     party  Average      5  free  Summer     o-neck
# 12    957723897      sexy      Low    4.7     M  Winter     o-neck
# ..          ...       ...      ...    ...   ...     ...        ...
# 513   957723897      sexy      Low    4.7     M  Winter     o-neck
# 514   749031896   vintage  Average    4.8     M  Summer     o-neck
# 515  1055411544    Casual      Low      5     M  Summer  boat-neck
# 517   624314841      cute  Average    4.7     L  spring     o-neck
# 518   830467746  bohemian   Medium      5  free  Automn     o-neck
#
#      SleeveLength waiseline       Material  FabricType  Decoration
# 0       sleevless    empire            NaN     chiffon     ruffles  \
# ...

# %%
len(df_attribute[df_attribute['Rating']>'3'])
# Out:
# 388

# %%
df_attribute[df_attribute['Rating']>'3']['Dress_ID']# Give me that Dress_ID which has Rating greater than 3
# Out:
# 0      1006032852
# 3       966005983
# 4       876339541
# 10     1117293701
# 12      957723897
#           ...
# 513     957723897
# 514     749031896
# 515    1055411544
# 517     624314841
# 518     830467746
# Name: Dress_ID, Length: 388, dtype: object

# %%
# Here we have uses the and operator
df_attribute[(df_attribute['Rating']>'3') & (df_attribute['Recommendation']>'0')]
# Out:
#        Dress_ID     Style    Price Rating  Size  Season NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer   o-neck  \
# 3     966005983     Brief  Average    4.6     L  Spring   o-neck
# 12    957723897      sexy      Low    4.7     M  Winter   o-neck
# 13    749031896   vintage  Average    4.8     M  Summer   o-neck
# 16    624314841      cute  Average    4.7     L  spring   o-neck
# ..          ...       ...      ...    ...   ...     ...      ...
# 504   966005983     Brief  Average    4.6     L  Spring   o-neck
# 513   957723897      sexy      Low    4.7     M  Winter   o-neck
# 514   749031896   vintage  Average    4.8     M  Summer   o-neck
# 517   624314841      cute  Average    4.7     L  spring   o-neck
# 518   830467746  bohemian   Medium      5  free  Automn   o-neck
#
#      SleeveLength waiseline Material FabricType  Decoration Pattern Type
# 0       sleevless    empire      NaN    chiffon     ruffles       animal  \
# ...

# %%
# Here we have uses the or operator
df_attribute[(df_attribute['Rating']>'3') | (df_attribute['Recommendation']>'0')]
# Out:
#        Dress_ID     Style    Price Rating  Size  Season   NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer     o-neck  \
# 3     966005983     Brief  Average    4.6     L  Spring     o-neck
# 4     876339541      cute      Low    4.5     M  Summer     o-neck
# 8    1113094204     Flare  Average      0  free  Spring     v-neck
# 9     985292672  bohemian      Low      0  free  Summer     v-neck
# ..          ...       ...      ...    ...   ...     ...        ...
# 513   957723897      sexy      Low    4.7     M  Winter     o-neck
# 514   749031896   vintage  Average    4.8     M  Summer     o-neck
# 515  1055411544    Casual      Low      5     M  Summer  boat-neck
# 517   624314841      cute  Average    4.7     L  spring     o-neck
# 518   830467746  bohemian   Medium      5  free  Automn     o-neck
#
#      SleeveLength waiseline       Material  FabricType  Decoration
# 0       sleevless    empire            NaN     chiffon     ruffles  \
# ...

# %%
df_attribute.dtypes
# Out:
# Dress_ID           object
# Style              object
# Price              object
# Rating             object
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# waiseline          object
# Material           object
# FabricType         object
# Decoration         object
# Pattern Type       object
# Recommendation     object
# Unnamed: 14       float64
# Date               object
# dtype: object

# %%
# Here we want to change the data type of the variable 
# Here we are changing the date datatype which is object into an date datatype
date=pd.to_datetime(df_attribute['Date'],format='%d-%m-%Y')
print(date)
# Out:
# 0     2023-01-01
# 1     2023-01-02
# 2     2023-01-03
# 3     2023-01-04
# 4     2023-01-05
#          ...
# 515   2024-05-30
# 516   2024-05-31
# 517   2024-06-01
# 518   2024-06-02
# 519   2015-06-03
# Name: Date, Length: 520, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# Creating the new column and assigning the converted data into that column
df_attribute['converted_order_date']=pd.to_datetime(df_attribute['Date'],format='%d-%m-%Y')

# %%
df_attribute
# Out:
#        Dress_ID     Style    Price Rating  Size  Season         NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low      0     L  Summer           o-neck
# 2    1190380701   vintage     High      0     L  Automn           o-neck
# 3     966005983     Brief  Average    4.6     L  Spring           o-neck
# 4     876339541      cute      Low    4.5     M  Summer           o-neck
# ..          ...       ...      ...    ...   ...     ...              ...
# 515  1055411544    Casual      Low      5     M  Summer        boat-neck
# 516  1162628131    Casual      Low      0  free  Winter        boat-neck
# 517   624314841      cute  Average    4.7     L  spring           o-neck
# 518   830467746  bohemian   Medium      5  free  Automn           o-neck
# 519   840857118     Brief  Average      0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline       Material FabricType  Decoration
# ...

# %%
# I want to extract year from the converted_order_date and store in the new column
df_attribute['order_date_year'] = df_attribute['converted_order_date'].dt.year

# %%
df_attribute
# Out:
#        Dress_ID     Style    Price Rating  Size  Season         NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low      0     L  Summer           o-neck
# 2    1190380701   vintage     High      0     L  Automn           o-neck
# 3     966005983     Brief  Average    4.6     L  Spring           o-neck
# 4     876339541      cute      Low    4.5     M  Summer           o-neck
# ..          ...       ...      ...    ...   ...     ...              ...
# 515  1055411544    Casual      Low      5     M  Summer        boat-neck
# 516  1162628131    Casual      Low      0  free  Winter        boat-neck
# 517   624314841      cute  Average    4.7     L  spring           o-neck
# 518   830467746  bohemian   Medium      5  free  Automn           o-neck
# 519   840857118     Brief  Average      0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline       Material FabricType  Decoration
# ...

# %%
# Here we are storing the months in the seperate column
df_attribute['order_date_month'] = df_attribute['converted_order_date'].dt.month

# %%
df_attribute
# Out:
#        Dress_ID     Style    Price Rating  Size  Season         NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low      0     L  Summer           o-neck
# 2    1190380701   vintage     High      0     L  Automn           o-neck
# 3     966005983     Brief  Average    4.6     L  Spring           o-neck
# 4     876339541      cute      Low    4.5     M  Summer           o-neck
# ..          ...       ...      ...    ...   ...     ...              ...
# 515  1055411544    Casual      Low      5     M  Summer        boat-neck
# 516  1162628131    Casual      Low      0  free  Winter        boat-neck
# 517   624314841      cute  Average    4.7     L  spring           o-neck
# 518   830467746  bohemian   Medium      5  free  Automn           o-neck
# 519   840857118     Brief  Average      0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline       Material FabricType  Decoration
# ...

# %%
# Here we are storing the months in the seperate column
df_attribute['order_date_week'] = df_attribute['converted_order_date'].dt.isocalendar().week

# %%
df_attribute
# Out:
#        Dress_ID     Style    Price Rating  Size  Season         NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low      0     L  Summer           o-neck
# 2    1190380701   vintage     High      0     L  Automn           o-neck
# 3     966005983     Brief  Average    4.6     L  Spring           o-neck
# 4     876339541      cute      Low    4.5     M  Summer           o-neck
# ..          ...       ...      ...    ...   ...     ...              ...
# 515  1055411544    Casual      Low      5     M  Summer        boat-neck
# 516  1162628131    Casual      Low      0  free  Winter        boat-neck
# 517   624314841      cute  Average    4.7     L  spring           o-neck
# 518   830467746  bohemian   Medium      5  free  Automn           o-neck
# 519   840857118     Brief  Average      0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline       Material FabricType  Decoration
# ...

# %%
df_attribute[['converted_order_date','order_date_week']]
# Out:
#     converted_order_date  order_date_week
# 0             2023-01-01               52
# 1             2023-01-02                1
# 2             2023-01-03                1
# 3             2023-01-04                1
# 4             2023-01-05                1
# ..                   ...              ...
# 515           2024-05-30               22
# 516           2024-05-31               22
# 517           2024-06-01               22
# 518           2024-06-02               22
# 519           2015-06-03               23
#
# [520 rows x 2 columns]

# %%
# We want that data where the year is 2015
df_attribute[df_attribute['order_date_year']==2015]
# Out:
#       Dress_ID  Style    Price Rating Size  Season         NeckLine
# 519  840857118  Brief  Average      0    M  Winter  peterpan-collor  \
#
#      SleeveLength waiseline Material FabricType Decoration Pattern Type
# 519  threequarter   natural   cotton        NaN        NaN    patchwork  \
#
#     Recommendation  Unnamed: 14        Date converted_order_date
# 519              0          NaN  03-06-2015           2015-06-03  \
#
#      order_date_year  order_date_month  order_date_week
# 519             2015                 6               23

# %%
df_attribute['Reviews'].value_counts() # Here the group by operation is known as value_counts()

# %%
# If you want to add the data of two or more column and add into the new column
# df['new_column'] = df['column1'] + df['column2']

# %%
df_attribute
# Out:
#        Dress_ID     Style    Price Rating  Size  Season         NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low      0     L  Summer           o-neck
# 2    1190380701   vintage     High      0     L  Automn           o-neck
# 3     966005983     Brief  Average    4.6     L  Spring           o-neck
# 4     876339541      cute      Low    4.5     M  Summer           o-neck
# ..          ...       ...      ...    ...   ...     ...              ...
# 515  1055411544    Casual      Low      5     M  Summer        boat-neck
# 516  1162628131    Casual      Low      0  free  Winter        boat-neck
# 517   624314841      cute  Average    4.7     L  spring           o-neck
# 518   830467746  bohemian   Medium      5  free  Automn           o-neck
# 519   840857118     Brief  Average      0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline       Material FabricType  Decoration
# ...

# %%
# If we want to delete the specific column
df_attribute.drop('Style',axis=1)
# We can delete row and  column by default the axis=0 which is row
# For row axis=0
# For column axis=1
# If we delete in these way in these scenario it is deleted but originally it is not deleted
# Out:
#        Dress_ID    Price Rating  Size  Season         NeckLine  SleeveLength
# 0    1006032852      Low    4.6     M  Summer           o-neck     sleevless  \
# 1    1212192089      Low      0     L  Summer           o-neck         Petal
# 2    1190380701     High      0     L  Automn           o-neck          full
# 3     966005983  Average    4.6     L  Spring           o-neck          full
# 4     876339541      Low    4.5     M  Summer           o-neck     butterfly
# ..          ...      ...    ...   ...     ...              ...           ...
# 515  1055411544      Low      5     M  Summer        boat-neck         short
# 516  1162628131      Low      0  free  Winter        boat-neck          full
# 517   624314841  Average    4.7     L  spring           o-neck         short
# 518   830467746   Medium      5  free  Automn           o-neck          full
# 519   840857118  Average      0     M  Winter  peterpan-collor  threequarter
#
# ...

# %%
df_attribute.head() # Here we run again the deleted column is there
# Out:
#      Dress_ID    Style    Price Rating Size  Season NeckLine SleeveLength
# 0  1006032852     Sexy      Low    4.6    M  Summer   o-neck    sleevless  \
# 1  1212192089   Casual      Low      0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High      0    L  Automn   o-neck         full
# 3   966005983    Brief  Average    4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low    4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type Recommendation
# 0    empire            NaN    chiffon     ruffles       animal              1  \
# 1   natural     microfiber        NaN     ruffles       animal              0
# 2   natural       polyster        NaN         NaN        print              0
# 3   natural           silk    chiffon  embroidary        print              1
# 4   natural  chiffonfabric    chiffon         bow          dot              0
#
#    Unnamed: 14        Date
# ...

# %%
# For permananet changes :-
# Store the df_attribute.drop('Style',axis=1) in new dataframe and then the changes are permanent
# Another method is inplace method
df_attribute.drop('Style',axis=1,inplace=True)

# %%
df_attribute
# Out:
#        Dress_ID    Price Rating  Size  Season         NeckLine  SleeveLength
# 0    1006032852      Low    4.6     M  Summer           o-neck     sleevless  \
# 1    1212192089      Low      0     L  Summer           o-neck         Petal
# 2    1190380701     High      0     L  Automn           o-neck          full
# 3     966005983  Average    4.6     L  Spring           o-neck          full
# 4     876339541      Low    4.5     M  Summer           o-neck     butterfly
# ..          ...      ...    ...   ...     ...              ...           ...
# 515  1055411544      Low      5     M  Summer        boat-neck         short
# 516  1162628131      Low      0  free  Winter        boat-neck          full
# 517   624314841  Average    4.7     L  spring           o-neck         short
# 518   830467746   Medium      5  free  Automn           o-neck          full
# 519   840857118  Average      0     M  Winter  peterpan-collor  threequarter
#
# ...

# %%
df_attribute.head()
# Out:
#      Dress_ID    Price Rating Size  Season NeckLine SleeveLength waiseline
# 0  1006032852      Low    4.6    M  Summer   o-neck    sleevless    empire  \
# 1  1212192089      Low      0    L  Summer   o-neck        Petal   natural
# 2  1190380701     High      0    L  Automn   o-neck         full   natural
# 3   966005983  Average    4.6    L  Spring   o-neck         full   natural
# 4   876339541      Low    4.5    M  Summer   o-neck    butterfly   natural
#
#         Material FabricType  Decoration Pattern Type Recommendation
# 0            NaN    chiffon     ruffles       animal              1  \
# 1     microfiber        NaN     ruffles       animal              0
# 2       polyster        NaN         NaN        print              0
# 3           silk    chiffon  embroidary        print              1
# 4  chiffonfabric    chiffon         bow          dot              0
#
#    Unnamed: 14        Date
# 0          NaN  01-01-2023
# 1          NaN  02-01-2023
# ...

# %%
# If we want to delete the row
df_attribute.drop(1)
# Out:
#        Dress_ID    Price Rating  Size  Season         NeckLine  SleeveLength
# 0    1006032852      Low    4.6     M  Summer           o-neck     sleevless  \
# 2    1190380701     High      0     L  Automn           o-neck          full
# 3     966005983  Average    4.6     L  Spring           o-neck          full
# 4     876339541      Low    4.5     M  Summer           o-neck     butterfly
# 5    1068332458      Low      0     M  Summer           v-neck     sleevless
# ..          ...      ...    ...   ...     ...              ...           ...
# 515  1055411544      Low      5     M  Summer        boat-neck         short
# 516  1162628131      Low      0  free  Winter        boat-neck          full
# 517   624314841  Average    4.7     L  spring           o-neck         short
# 518   830467746   Medium      5  free  Automn           o-neck          full
# 519   840857118  Average      0     M  Winter  peterpan-collor  threequarter
#
# ...

# %%
df_attribute
# Out:
#        Dress_ID    Price Rating  Size  Season         NeckLine  SleeveLength
# 0    1006032852      Low    4.6     M  Summer           o-neck     sleevless  \
# 1    1212192089      Low      0     L  Summer           o-neck         Petal
# 2    1190380701     High      0     L  Automn           o-neck          full
# 3     966005983  Average    4.6     L  Spring           o-neck          full
# 4     876339541      Low    4.5     M  Summer           o-neck     butterfly
# ..          ...      ...    ...   ...     ...              ...           ...
# 515  1055411544      Low      5     M  Summer        boat-neck         short
# 516  1162628131      Low      0  free  Winter        boat-neck          full
# 517   624314841  Average    4.7     L  spring           o-neck         short
# 518   830467746   Medium      5  free  Automn           o-neck          full
# 519   840857118  Average      0     M  Winter  peterpan-collor  threequarter
#
# ...

# %%
# For permanent removal of the row use inplace=True
df_attribute.drop(1,inplace=True)

# %%
df_attribute
# Out:
#        Dress_ID    Price Rating  Size  Season         NeckLine  SleeveLength
# 0    1006032852      Low    4.6     M  Summer           o-neck     sleevless  \
# 2    1190380701     High      0     L  Automn           o-neck          full
# 3     966005983  Average    4.6     L  Spring           o-neck          full
# 4     876339541      Low    4.5     M  Summer           o-neck     butterfly
# 5    1068332458      Low      0     M  Summer           v-neck     sleevless
# ..          ...      ...    ...   ...     ...              ...           ...
# 515  1055411544      Low      5     M  Summer        boat-neck         short
# 516  1162628131      Low      0  free  Winter        boat-neck          full
# 517   624314841  Average    4.7     L  spring           o-neck         short
# 518   830467746   Medium      5  free  Automn           o-neck          full
# 519   840857118  Average      0     M  Winter  peterpan-collor  threequarter
#
# ...

# %%
# Performing the row operation
#Filtering out the rows data
df_attribute.loc[[2,4]] # It will give the record 2 and the record 4
# Out:
#      Dress_ID    Style Price Rating Size  Season NeckLine SleeveLength
# 2  1190380701  vintage  High      0    L  Automn   o-neck         full  \
# 4   876339541     cute   Low    4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType Decoration Pattern Type Recommendation
# 2   natural       polyster        NaN        NaN        print              0  \
# 4   natural  chiffonfabric    chiffon        bow          dot              0
#
#    Unnamed: 14        Date
# 2          NaN  03-01-2023
# 4          NaN  05-01-2023

# %%
# Here we are using the range function for filtering out the record # Range from 2 to 10
df_attribute.loc[2:10]
# Out:
#       Dress_ID     Style    Price Rating  Size  Season NeckLine SleeveLength
# 2   1190380701   vintage     High      0     L  Automn   o-neck         full  \
# 3    966005983     Brief  Average    4.6     L  Spring   o-neck         full
# 4    876339541      cute      Low    4.5     M  Summer   o-neck    butterfly
# 5   1068332458  bohemian      Low      0     M  Summer   v-neck    sleevless
# 6   1220707172    Casual  Average      0    XL  Summer   o-neck         full
# 7   1219677488   Novelty  Average      0  free  Automn   o-neck        short
# 8   1113094204     Flare  Average      0  free  Spring   v-neck        short
# 9    985292672  bohemian      Low      0  free  Summer   v-neck    sleevless
# 10  1117293701     party  Average      5  free  Summer   o-neck         full
#
#    waiseline       Material  FabricType  Decoration Pattern Type
# 2    natural       polyster         NaN         NaN        print  \
# 3    natural           silk     chiffon  embroidary        print
# ...

# %%
df_attribute.loc[2:10:2] # Here we are fetching the 10 records at the jump of 2
# Out:
#       Dress_ID    Style    Price Rating  Size  Season NeckLine SleeveLength
# 2   1190380701  vintage     High      0     L  Automn   o-neck         full  \
# 4    876339541     cute      Low    4.5     M  Summer   o-neck    butterfly
# 6   1220707172   Casual  Average      0    XL  Summer   o-neck         full
# 8   1113094204    Flare  Average      0  free  Spring   v-neck        short
# 10  1117293701    party  Average      5  free  Summer   o-neck         full
#
#    waiseline       Material  FabricType Decoration Pattern Type
# 2    natural       polyster         NaN        NaN        print  \
# 4    natural  chiffonfabric     chiffon        bow          dot
# 6        NaN         cotton         NaN        NaN        solid
# 8     empire         cotton  broadcloth    beading        solid
# 10   natural       polyster  broadcloth       lace        solid
#
#    Recommendation  Unnamed: 14        Date
# 2               0          NaN  03-01-2023
# ...

# %%
# Fetching the rows from 0 to 4 and column index 0 to 2
df_attribute.loc[0:4,['Dress_ID','Style']]
# Out:
#      Dress_ID    Style
# 0  1006032852     Sexy
# 1  1212192089   Casual
# 2  1190380701  vintage
# 3   966005983    Brief
# 4   876339541     cute

# %%
# Doing the above operation with the help of iloc
df_attribute.iloc[0:4,0:3]
# Out:
#      Dress_ID    Style    Price
# 0  1006032852     Sexy      Low
# 1  1212192089   Casual      Low
# 2  1190380701  vintage     High
# 3   966005983    Brief  Average

# %%
# iloc -> Understands the default one
# loc-> Understands the name given by user or not it can understand the default one

# %%
df_attribute.iloc[2:6,3:6]
# Out:
#   Rating Size  Season
# 2      0    L  Automn
# 3    4.6    L  Spring
# 4    4.5    M  Summer
# 5      0    M  Summer

# %%
df_attribute
# Out:
#        Dress_ID     Style    Price Rating  Size  Season         NeckLine
# 0    1006032852      Sexy      Low    4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low      0     L  Summer           o-neck
# 2    1190380701   vintage     High      0     L  Automn           o-neck
# 3     966005983     Brief  Average    4.6     L  Spring           o-neck
# 4     876339541      cute      Low    4.5     M  Summer           o-neck
# ..          ...       ...      ...    ...   ...     ...              ...
# 515  1055411544    Casual      Low      5     M  Summer        boat-neck
# 516  1162628131    Casual      Low      0  free  Winter        boat-neck
# 517   624314841      cute  Average    4.7     L  spring           o-neck
# 518   830467746  bohemian   Medium      5  free  Automn           o-neck
# 519   840857118     Brief  Average      0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline       Material FabricType  Decoration
# ...

# %%
# Changing the name of the column usinf rename function
df_attribute.rename(columns={'Rating':'Ratings'},inplace=True)

# %%
df_attribute
# Out:
#        Dress_ID     Style    Price Ratings  Size  Season         NeckLine
# 0    1006032852      Sexy      Low     4.6     M  Summer           o-neck  \
# 1    1212192089    Casual      Low       0     L  Summer           o-neck
# 2    1190380701   vintage     High       0     L  Automn           o-neck
# 3     966005983     Brief  Average     4.6     L  Spring           o-neck
# 4     876339541      cute      Low     4.5     M  Summer           o-neck
# ..          ...       ...      ...     ...   ...     ...              ...
# 515  1055411544    Casual      Low       5     M  Summer        boat-neck
# 516  1162628131    Casual      Low       0  free  Winter        boat-neck
# 517   624314841      cute  Average     4.7     L  spring           o-neck
# 518   830467746  bohemian   Medium       5  free  Automn           o-neck
# 519   840857118     Brief  Average       0     M  Winter  peterpan-collor
#
#      SleeveLength waiseline       Material FabricType  Decoration
# ...

# %%
# Changing the name of the row using the rename method
df_attribute.rename(index={0: '0th_row'}, inplace=True)

# %%
df_attribute
# Out:
#            Dress_ID     Style    Price Ratings  Size  Season         NeckLine
# 0th_row  1006032852      Sexy      Low     4.6     M  Summer           o-neck  \
# 1        1212192089    Casual      Low       0     L  Summer           o-neck
# 2        1190380701   vintage     High       0     L  Automn           o-neck
# 3         966005983     Brief  Average     4.6     L  Spring           o-neck
# 4         876339541      cute      Low     4.5     M  Summer           o-neck
# ...             ...       ...      ...     ...   ...     ...              ...
# 515      1055411544    Casual      Low       5     M  Summer        boat-neck
# 516      1162628131    Casual      Low       0  free  Winter        boat-neck
# 517       624314841      cute  Average     4.7     L  spring           o-neck
# 518       830467746  bohemian   Medium       5  free  Automn           o-neck
# 519       840857118     Brief  Average       0     M  Winter  peterpan-collor
#
# ...

# %%
# Accesing the row by it's new row name
df_attribute.loc[['0th_row']]
# Out:
#            Dress_ID Style Price Ratings Size  Season NeckLine SleeveLength
# 0th_row  1006032852  Sexy   Low     4.6    M  Summer   o-neck    sleevless  \
#
#         waiseline Material FabricType Decoration Pattern Type Recommendation
# 0th_row    empire      NaN    chiffon    ruffles       animal              1  \
#
#          Unnamed: 14        Date
# 0th_row          NaN  01-01-2023

# %%
# Here we are filtering the data types which have datatype equal to float64
df_attribute.dtypes[(df_attribute.dtypes=='float64')]
# Out:
# Unnamed: 14    float64
# dtype: object

# %%
# Filtering out that data which do not has data type float64
df_attribute.dtypes[df_attribute.dtypes!='float64']
# Out:
# Dress_ID          object
# Style             object
# Price             object
# Ratings           object
# Size              object
# Season            object
# NeckLine          object
# SleeveLength      object
# waiseline         object
# Material          object
# FabricType        object
# Decoration        object
# Pattern Type      object
# Recommendation    object
# Date              object
# dtype: object

# %%
# Storing the df_attribute.dtypes[(df_attribute.dtypes=='float64')] in df
df2=df_attribute.dtypes[(df_attribute.dtypes=='float64')]
# Out:
# Unnamed: 14    float64
# dtype: object

# %%
# If we want to drop the row or column which consists of the null value 
# dataframe_name.dropna() By default it will drop the row even a single null value is there it will drop whole value

# %%
# If we want to drop the column consisiting of null value and even one null value then also it will drop
# dataframe_name.drop(axis=1)

# %%
# If we want to apply the condition on the count of the Nan values
# dateframe_name.dropna(thresh=n) # Atleast n Nan values

# %%
# If we want to fill the Nan values with the particular values then will use
# dataframe_name.fillna(value=n) It will fill with the all the Nan values with the n values

# %%
# Replacing Nan value with the mean of the column
# dataframe_name.fillna(value=dataframe_name['column_name'].mean())

# %%
df_attribute
# Out:
#            Dress_ID     Style    Price Ratings  Size  Season         NeckLine
# 0th_row  1006032852      Sexy      Low     4.6     M  Summer           o-neck  \
# 1        1212192089    Casual      Low       0     L  Summer           o-neck
# 2        1190380701   vintage     High       0     L  Automn           o-neck
# 3         966005983     Brief  Average     4.6     L  Spring           o-neck
# 4         876339541      cute      Low     4.5     M  Summer           o-neck
# ...             ...       ...      ...     ...   ...     ...              ...
# 515      1055411544    Casual      Low       5     M  Summer        boat-neck
# 516      1162628131    Casual      Low       0  free  Winter        boat-neck
# 517       624314841      cute  Average     4.7     L  spring           o-neck
# 518       830467746  bohemian   Medium       5  free  Automn           o-neck
# 519       840857118     Brief  Average       0     M  Winter  peterpan-collor
#
# ...

# %%
# Challeneges for the next session
1-> Dataset:- Agent Performance Report
# For each agent what is the weekly ratiny that you have solvedg (Only for 5 days)

# . Find out there avarage rating on weekly basis keep this in a mind that they take two days of le
# 1
# . Total working days for each agents
# 2
# Total query that you hvae taken
# 3.
# total Feedback that you have received
# 4.
# a agent name who have average rating between 3.5 to 4
# 5.
# Agent name who have rating lesss then 3.5
# 6.
# agent name who have rating more then 4.5
# how many feedaback agents have received more then 4.5 average
# 8.
# . average weekly response time for each agent
# 9
# average weekely resolution time for each agents
# 10 .
# list of all agents name
# 11 .
# percentage of chat on which they have received a feedback
# 12
# Total contributation hour for each and every agents weekly basis
# 13 .
# total percentage of active hour for a month
# 14.

# %%
# Dataset is available in the form of the dictionary
data={'name':['sudh','krish','hitest','telusko'],'salary':[100,200,300,400],
      
        'mail_id' : ['sudh@inuron.ai','krish@inuron.ai','hites@inuron.ai','telisko@inuron.ai'],
        'addr' :['blr','blr','blr','mum']
}
# Now we have to convert these dictionary into dataset
df=pd.DataFrame(data)

# %%
# Changing the index of the row
pd.DataFrame(data,index=[4,5,6,7])
# Out:
#       name  salary            mail_id addr
# 4     sudh     100     sudh@inuron.ai  blr
# 5    krish     200    krish@inuron.ai  blr
# 6   hitest     300    hites@inuron.ai  blr
# 7  telusko     400  telisko@inuron.ai  mum

# %%
df=pd.DataFrame(data,index=[4,5,6,7])

# %%
df.loc[5]
# Out:
# name                 krish
# salary                 200
# mail_id    krish@inuron.ai
# addr                   blr
# Name: 5, dtype: object

# %%
df.loc[5:6]
# Out:
#      name  salary          mail_id addr
# 5   krish     200  krish@inuron.ai  blr
# 6  hitest     300  hites@inuron.ai  blr

# %%
# iloc always looks for the default index
# loc always looks for the given index that was given bu the user
# Here no output will come
df.iloc[5:6]
# Out:
# Empty DataFrame
# Columns: [name, salary, mail_id, addr]
# Index: []

# %%
# Here we are going with the default index
df.iloc[1:3]
# Out:
#      name  salary          mail_id addr
# 5   krish     200  krish@inuron.ai  blr
# 6  hitest     300  hites@inuron.ai  blr

# %%
# String indexing is also possible
df=pd.DataFrame(data,index=['sudh','krish','hitesh','telusko'])

# %%
df
# Out:
#             name  salary            mail_id addr
# sudh        sudh     100     sudh@inuron.ai  blr
# krish      krish     200    krish@inuron.ai  blr
# hitesh    hitest     300    hites@inuron.ai  blr
# telusko  telusko     400  telisko@inuron.ai  mum

# %%
df=pd.DataFrame(data,index=['0','1','2','3'])

# %%
df
# Out:
#       name  salary            mail_id addr
# 0     sudh     100     sudh@inuron.ai  blr
# 1    krish     200    krish@inuron.ai  blr
# 2   hitest     300    hites@inuron.ai  blr
# 3  telusko     400  telisko@inuron.ai  mum

# %%
# Creating the dictionary data1
data1={'pf_nu':[234,45,54465,656],'income_tax':[234,565,767,6778],'courses':['ds','bigdata','web dev','blockchain']
}
df1=pd.DataFrame(data1)

# %%
df1
# Out:
#    pf_nu  income_tax     courses
# 0    234         234          ds
# 1     45         565     bigdata
# 2  54465         767     web dev
# 3    656        6778  blockchain

# %%
df
# Out:
#       name  salary            mail_id addr
# 0     sudh     100     sudh@inuron.ai  blr
# 1    krish     200    krish@inuron.ai  blr
# 2   hitest     300    hites@inuron.ai  blr
# 3  telusko     400  telisko@inuron.ai  mum

# %%
# Here we want to merge the df and the df1
# We can merge it vertically and the horizontally
pd.concat([df,df1])
# Here we have done horizontal concatination
# Out:
#       name  salary            mail_id addr    pf_nu  income_tax     courses
# 0     sudh   100.0     sudh@inuron.ai  blr      NaN         NaN         NaN
# 1    krish   200.0    krish@inuron.ai  blr      NaN         NaN         NaN
# 2   hitest   300.0    hites@inuron.ai  blr      NaN         NaN         NaN
# 3  telusko   400.0  telisko@inuron.ai  mum      NaN         NaN         NaN
# 0      NaN     NaN                NaN  NaN    234.0       234.0          ds
# 1      NaN     NaN                NaN  NaN     45.0       565.0     bigdata
# 2      NaN     NaN                NaN  NaN  54465.0       767.0     web dev
# 3      NaN     NaN                NaN  NaN    656.0      6778.0  blockchain

# %%
df=pd.DataFrame(data)

# %%
# Column wise concatination when axis=1
pd.concat([df,df1],axis=1)
# Out:
#       name  salary            mail_id addr  pf_nu  income_tax     courses
# 0     sudh     100     sudh@inuron.ai  blr    234         234          ds
# 1    krish     200    krish@inuron.ai  blr     45         565     bigdata
# 2   hitest     300    hites@inuron.ai  blr  54465         767     web dev
# 3  telusko     400  telisko@inuron.ai  mum    656        6778  blockchain

# %%
data2={'0':['sudh','krish','hitest','telusko'],'1':[100,200,300,400],
      
        '2' : ['sudh@inuron.ai','krish@inuron.ai','hites@inuron.ai','telisko@inuron.ai'],
        '3' :['blr','blr','blr','mum']
}

# %%
data3={'0':[234,45,54465,656],'1':[234,565,767,6778],'2':['23543','43523','454','5656'],'3':['ds','bigdata','web dev','blockchain']
}

# %%
df2=pd.DataFrame(data2)

# %%
df3=pd.DataFrame(data3)

# %%
# Here our column name are same or key is same that is why we are not getting any Nan values at the time of concatination
pd.concat([df2,df3])
# Out:
#          0     1                  2           3
# 0     sudh   100     sudh@inuron.ai         blr
# 1    krish   200    krish@inuron.ai         blr
# 2   hitest   300    hites@inuron.ai         blr
# 3  telusko   400  telisko@inuron.ai         mum
# 0      234   234              23543          ds
# 1       45   565              43523     bigdata
# 2    54465   767                454     web dev
# 3      656  6778               5656  blockchain

# %%
data4 = {
    'emp_id':[101,102,103,104],
    'salary':[234,345,200,400],
    'pf':[23,34,56,78]
}

# %%
data5={
    'emp_id':[101,102,104,105],
    'mob_no':[3434,5656,767,878],
    'house_no':[345,345,345,56]
}

# %%
df4=pd.DataFrame(data4)

# %%
df4
# Out:
#    emp_id  salary  pf
# 0     101     234  23
# 1     102     345  34
# 2     103     200  56
# 3     104     400  78

# %%
df5=pd.DataFrame(data5)

# %%
df
# Out:
#       name  salary            mail_id addr
# 0     sudh     100     sudh@inuron.ai  blr
# 1    krish     200    krish@inuron.ai  blr
# 2   hitest     300    hites@inuron.ai  blr
# 3  telusko     400  telisko@inuron.ai  mum

# %%
# Merge Oprearion -> By default it will take the common data based on the common column name
pd.merge(df4,df5)
# Out:
#    emp_id  salary  pf  mob_no  house_no
# 0     101     234  23    3434       345
# 1     102     345  34    5656       345
# 2     104     400  78     767       345

# %%
df4
# Out:
#    emp_id  salary  pf
# 0     101     234  23
# 1     102     345  34
# 2     103     200  56
# 3     104     400  78

# %%
df5
# Out:
#    emp_id  mob_no  house_no
# 0     101    3434       345
# 1     102    5656       345
# 2     104     767       345
# 3     105     878        56

# %%
# Left merge operation -> Take the left of the dataset and the common of both the dataset
pd.merge(df4,df5,how='left')
# Out:
#    emp_id  salary  pf  mob_no  house_no
# 0     101     234  23  3434.0     345.0
# 1     102     345  34  5656.0     345.0
# 2     103     200  56     NaN       NaN
# 3     104     400  78   767.0     345.0

# %%
# Left merge operation -> Take the right of the dataset and the common of both the dataset
pd.merge(df4,df5,how='right')
# Out:
#    emp_id  salary    pf  mob_no  house_no
# 0     101   234.0  23.0    3434       345
# 1     102   345.0  34.0    5656       345
# 2     104   400.0  78.0     767       345
# 3     105     NaN   NaN     878        56

# %%
# Outer and Cross merge operation is also possible

# %%
pd.merge(df4,df5,how='right',on='emp_id')
# Out:
#    emp_id  salary    pf  mob_no  house_no
# 0     101   234.0  23.0    3434       345
# 1     102   345.0  34.0    5656       345
# 2     104   400.0  78.0     767       345
# 3     105     NaN   NaN     878        56

# %%
data6 = {
    'emp_id1':[101,102,103,104],
    'salary':[234,345,200,400],
    'pf':[23,34,56,78]
}

# %%
data7={
    'emp_id2':[101,102,104,105],
    'mob_no':[3434,5656,767,878],
    'house_no':[345,345,345,56]
}

# %%
df6=pd.DataFrame(data6)

# %%
df7=pd.DataFrame(data7)

# %%
df6
# Out:
#    emp_id1  salary  pf
# 0      101     234  23
# 1      102     345  34
# 2      103     200  56
# 3      104     400  78

# %%
df7
# Out:
#    emp_id2  mob_no  house_no
# 0      101    3434       345
# 1      102    5656       345
# 2      104     767       345
# 3      105     878        56

# %%
# In the above two dataset there is no comman column
pd.merge(df6,df7) # Here error will come because column name is not same
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[88], line 2
#       1 # In the above two dataset there is no comman column
# ----> 2 pd.merge(df6,df7)
#
# File c:\Python311\Lib\site-packages\pandas\core\reshape\merge.py:142, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     125 @Substitution("\nleft : DataFrame or named Series")
#     126 @Appender(_merge_doc, indents=0)
#     127 def merge(
#    (...)
#     140     validate: str | None = None,
#     141 ) -> DataFrame:
# --> 142     op = _MergeOperation(
#     143         left,
#     144         right,
#     145         how=how,
#     146         on=on,
#     147         left_on=left_on,
#     148         right_on=right_on,
#     149         left_index=left_index,
#     150         right_index=right_index,
#     151         sort=sort,
# ...

# %%
# Column name is not same but we want to performe the merge operation
pd.merge(df6,df7,left_on='emp_id1',right_on='emp_id2') # By default inner join will be performed
# Out:
#    emp_id1  salary  pf  emp_id2  mob_no  house_no
# 0      101     234  23      101    3434       345
# 1      102     345  34      102    5656       345
# 2      104     400  78      104     767       345

# %%
data8 = {
    'emp_id':[101,102,103,104],
    'salary':[234,5656,200,400],
    'pf':[23,34,56,78]
}

# %%
data9={
    'emp_id':[101,102,104,105],
    'salary':[234,5656,767,878],
    'house_no':[345,345,345,56]
}

# %%
df8=pd.DataFrame(data8)

# %%
df9=pd.DataFrame(data9)

# %%
df8
# Out:
#    emp_id  salary  pf
# 0     101     234  23
# 1     102     345  34
# 2     103     200  56
# 3     104     400  78

# %%
df9
# Out:
#    emp_id  salary  house_no
# 0     101    3434       345
# 1     102    5656       345
# 2     104     767       345
# 3     105     878        56

# %%
# We want to perform the merge operation on the emp_id and salary
# If the data in both the column are same then only it will print the data
pd.merge(df8,df9,on=['emp_id','salary'])
# Out:
#    emp_id  salary  pf  house_no
# 0     101     234  23       345
# 1     102    5656  34       345

# %%
df8.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data10 = {
    'emp_id1':[101,102,103,104],
    'salary1':[234,5656,200,400],
    'pf':[23,34,56,78]
}

# %%
data11={
    'emp_id2':[101,102,104,105,123],
    'salary2':[234,5656,767,878,43],
    'house_no':[345,345,345,56,234]
}

# %%
df10=pd.DataFrame(data10,index=['a','b','c','d'])

# %%
df11=pd.DataFrame(data11,index=['a','b','d','e','f'])

# %%
df10
# Out:
#    emp_id1  salary1  pf
# a      101      234  23
# b      102     5656  34
# c      103      200  56
# d      104      400  78

# %%
df11
# Out:
#    emp_id2  salary2  house_no
# a      101      234       345
# b      102     5656       345
# c      104      767       345
# d      105      878        56

# %%
# Performing the join operation
df10.join(df11) # By default it will do the left join
# Out:
#    emp_id1  salary1  pf  emp_id2  salary2  house_no
# a      101      234  23      101      234       345
# b      102     5656  34      102     5656       345
# c      103      200  56      104      767       345
# d      104      400  78      105      878        56

# %%
# Merge-> Column Name
# Join-> Row Index
